# %%
import sys
sys.path.append('../gansegmentation/face-parsing.PyTorch')
sys.path.append('../GAN_analy/genforce')

from models.stylegan2_generator import *
from models.stylegan2_discriminator import *
from models import *
from tqdm import tqdm
from VGG16_pre import *
from matplotlib import gridspec

from model import *
from resnet import *
from transform import *
from make_model import *

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8562fde5e156> in <module>
#      13 from resnet import *
#      14 from transform import *
# ---> 15 from make_model import *
#      16
#      17 import matplotlib.pyplot as plt
#
# ~/Research/make_model.py in <module>
#       4 sys.path.append('../GAN_analy/genforce')
#       5
# ----> 6 from stylegan2_generator import *
#       7 from stylegan2_discriminator import *
#       8
#
# ~/GAN_analy/genforce/models/stylegan2_generator.py in <module>
#      17 import torch.nn.functional as F
#      18
# ---> 19 from .sync_op import all_gather
#      20
#      21 __all__ = ['StyleGAN2Generator']
#
# ImportError: attempted relative import with no known parent package

# %%
device = 'cuda:4' if torch.cuda.is_available() else 'cpu'

# %%
seg_net = make_model()
seg_net.to(device)
print()

# %%
img_path = '../GAN_analy/genforce/name.jpg'
image = img_process(img_path)

plt.imshow(image[0].permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image = image.to(device)
seg_out = seg_net(image)

# %%
# 6 class 가 glasses 인듯.

# %%
with torch.no_grad():
    parsing = seg_out[0].squeeze(0).cpu().numpy().argmax(0)
    parsing = (parsing == 6)
    plt.imshow(parsing)
